# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulsemedShalo/Gute-Project/blob/main/histogramsAll.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
import matplotlib.pyplot as plt

# the path for a testing dataframe
file_path_test="/content/tester.csv"
file_path_train="/content/trainer.csv"


df_trainer = pd.read_csv(file_path_train,nrows = nRowsRead)
df_tester = pd.read_csv(file_path_test,nrows = nRowsRead)
# describing both the test and train dataframes


df_trainer.dataframeName = 'trainer.csv'
df_tester.dataframeName =  'tester.csv'

df_trainer['Label'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Label data frame')
plt.show()

df_tester['Label'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Label data frame')
plt.show()


# Get the number of frequencies
num_frequencies = df_trainer['Label'].value_counts()
num_frequencies2 = df_tester['Label'].value_counts()

# Print the number of frequencies
print(num_frequencies)
print(num_frequencies2)


df_trainer['Destination_Port'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Destination_Port data frame')
plt.show()

df_tester['Destination_Port'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Destination_Port data frame')
plt.show()


df_trainer['Flow_Duration'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Flow_Duration data frame')
plt.show()

df_tester['Flow_Duration'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Flow_Duration data frame')
plt.show()

df_trainer['Total_Fwd_Packets'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Total_Fwd_Packets data frame')
plt.show()

df_tester['Total_Fwd_Packets'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Total_Fwd_Packets data frame')
plt.show()


df_trainer['Total_Backward_Packets'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Total_Backward_Packets data frame')
plt.show()

df_tester['Total_Backward_Packets'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Total_Backward_Packets data frame')
plt.show()


df_trainer['Total_Length_of_Fwd_Packets'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Total_Length_of_Fwd_Packets data frame')
plt.show()

df_tester['Total_Length_of_Fwd_Packets'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Total_Length_of_Fwd_Packets data frame')
plt.show()

df_trainer['Total_Length_of_Bwd_Packets'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Total_Length_of_Bwd_Packets data frame')
plt.show()

df_tester['Total_Length_of_Bwd_Packets'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Total_Length_of_Bwd_Packets data frame')
plt.show()


df_trainer['Fwd_Packet_Length_Max'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Fwd_Packet_Length_Max data frame')
plt.show()

df_tester['Fwd_Packet_Length_Max'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Fwd_Packet_Length_Max data frame')
plt.show()


df_trainer['Fwd_Packet_Length_Min'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Fwd_Packet_Length_Min data frame')
plt.show()

df_tester['Fwd_Packet_Length_Min'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Fwd_Packet_Length_Min data frame')
plt.show()

df_trainer['Fwd_Packet_Length_Mean'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Fwd_Packet_Length_Mean data frame')
plt.show()

df_tester['Fwd_Packet_Length_Mean'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Fwd_Packet_Length_Mean data frame')
plt.show()


df_trainer['Fwd_Packet_Length_Std'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Fwd_Packet_Length_Std data frame')
plt.show()

df_tester['Fwd_Packet_Length_Std'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Fwd_Packet_Length_Std data frame')
plt.show()


df_trainer['Active_Std'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Active_Std data frame')
plt.show()

df_tester['Active_Mean'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Active_Mean data frame')
plt.show()

df_trainer['Active_Max'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Active_Max data frame')
plt.show()

df_tester['Active_Min'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Active_Min data frame')
plt.show()


df_trainer['Idle_Std'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Idle_Std data frame')
plt.show()

df_tester['Idle_Mean'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Idle_Mean data frame')
plt.show()


df_trainer['Idle_Max'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Idle_Max data frame')
plt.show()

df_tester['Idle_Min'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for Idle_Min data frame')
plt.show()
# Out:
# BENIGN           23053
# DoS Hulk         19517
# DoS slowloris     8028
# Name: Label, dtype: int64
# BENIGN           16216
# DoS Hulk         13290
# DoS slowloris     5550
# Name: Label, dtype: int64
