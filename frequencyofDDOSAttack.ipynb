# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulsemedShalo/Gute-Project/blob/main/frequencyofDDOSAttack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
import matplotlib.pyplot as plt


nRowsRead = None

# the path for a testing dataframe
file_path_test="/content/tester.csv"
file_path_train="/content/trainer.csv"


df_trainer = pd.read_csv(file_path_train,nrows = nRowsRead)
df_tester = pd.read_csv(file_path_test,nrows = nRowsRead)
# describing both the test and train dataframes


df_trainer.dataframeName = 'trainer.csv'
df_tester.dataframeName =  'tester.csv'

#print(df_trainer.isna())
#print(df_trainer.dtypes)

nRowsNum, nCol = df_trainer.shape
nRowsNum2, nCol2 = df_tester.shape

print(f'There are {nRowsNum} rows and {nCol} columns for training dataframe')
print(f'There are {nRowsNum2} rows and {nCol2} columns for testing dataframe')

df_trainer['Label'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for training data frame')
plt.show()

df_tester['Label'].hist()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram plot for testing data frame')
plt.show()

# Get the number of frequencies
num_frequencies = df_trainer['Label'].value_counts()

num_frequencies2 = df_tester['Label'].value_counts()

# Print the number of frequencies
print(num_frequencies)
print(num_frequencies2)
# Out:
# There are 50598 rows and 78 columns for training dataframe
# There are 35056 rows and 78 columns for testing dataframe
# BENIGN           23053
# DoS Hulk         19517
# DoS slowloris     8028
# Name: Label, dtype: int64
# BENIGN           16216
# DoS Hulk         13290
# DoS slowloris     5550
# Name: Label, dtype: int64
